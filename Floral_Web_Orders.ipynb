# %%
#Numpy
import numpy as np

#Pandas
import pandas as pd

#Seaborn
import seaborn as sns

#matplotlib
import matplotlib.pyplot as plt
import plotly

#Sklearn preprocessing
from sklearn import preprocessing,set_config
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,StandardScaler,LabelEncoder

#Sklearn Models
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn import preprocessing, set_config
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer,make_column_selector,make_column_transformer
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.decomposition import PCA
warnings.filterwarnings("ignore")
set_config(display = 'diagram')

#Sklearn Metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, roc_auc_score, roc_curve, classification_report

# %%
#Importing the web order data
wo = pd.read_csv("C:/Users/davyd/OneDrive/Desktop/website_orders_january_1_2019-june_6_2023.csv")
wo.head()
# Out:
#    Order Number  Order Source   Sale Date Delivery Date Order Status  \
# 0    1610507257  Premium Site  2018-12-21    2019-01-25    Delivered
# 1    2343172543  Premium Site  2018-12-31    2019-01-03    Delivered
# 2    5918429245  Premium Site  2019-01-01    2019-01-02    Delivered
# 3    7297751403  Premium Site  2019-01-01    2019-01-04    Delivered
# 4    4878369502  Premium Site  2019-01-02    2019-01-03    Delivered
#
#   Delivery Method                          Product Name Item Number  \
# 0  Local Delivery                        Vivid Daydream         NaN
# 1         Pick Up                         Cabernet Kiss         NaN
# 2  Local Delivery  Spring's Happy Kiss - upgrade:deluxe         NaN
# 3  Local Delivery                        Vivid Daydream         NaN
# 4  Local Delivery  Phalaenopsis orchid in barn wood box         NaN
#
#                                         Card Message Card Signature  ...  \
# 0  Happy Birthday, Camille! Wishing you a Special...            NaN  ...
# 1  Happy Birthday from all of us.\nPaul, Genny , ...            NaN  ...
# 2  Mr. And Mrs. Alday -\nThank you SO much for ha...            NaN  ...
# 3  Harald & Denair,\nYou are very dear to our hea...            NaN  ...
# 4  Seth & Jamie, \nI am so sorry I was unable to ...            NaN  ...
#
#    Billing State Billing Zip Subtotal Delivery Sale Tax Tip Discount  \
# 0      Tennessee       37064     85.0     15.0     8.29 NaN      0.0
# 1  Massachusetts       01034     55.0      0.0     5.36 NaN      0.0
# 2       New York       10011    125.0     15.0    12.19 NaN      0.0
# 3       Virginia       22556     85.0     15.0     8.29 NaN      0.0
# 4      Tennessee       37064     95.0     15.0     9.26 NaN      0.0
#
#    Grand Total Tax Exempt Payment Method
# 0       108.29        NaN    Credit Card
# 1        60.36        NaN    Credit Card
# 2       152.19        NaN    Credit Card
# 3       108.29        NaN    Credit Card
# 4       119.26        NaN    Credit Card
#
# [5 rows x 37 columns]
